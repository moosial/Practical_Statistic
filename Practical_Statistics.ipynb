# %% [markdown]
# # Simulating Coin Flips

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# outcome of one coin flip
np.random.randint(2)
# Out:
# 1

# %%
# outcomes of ten thousand coin flips
np.random.randint(2, size=10000)
# Out:
# array([1, 0, 0, ..., 0, 1, 1])

# %%
# mean outcome of ten thousand coin flips
np.random.randint(2, size=10000).mean()
# Out:
# 0.5005

# %%
# outcome of one coin flip
np.random.choice([0, 1])
# Out:
# 0

# %%
# outcome of ten thousand coin flips
np.random.choice([0, 1], size=10000)
# Out:
# array([1, 1, 1, ..., 0, 0, 1])

# %%
# mean outcome of ten thousand coin flips
np.random.choice([0, 1], size=10000).mean()
# Out:
# 0.5108

# %%
# outcomes of ten thousand biased coin flips
np.random.choice([0, 1], size=10000, p=[0.8, 0.2])
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
# mean outcome of ten thousand biased coin flips
np.random.choice([0, 1], size=10000, p=[0.8, 0.2]).mean()
# Out:
# 0.1988

# %% [markdown]
# # Coin Flips and Die Rolls
# Use NumPy to create simulations and compute proportions for the following outcomes. The first one is done for you.
#
# **Please note again that we are using 0 to represent heads, and 1 to represent tails.**

# %% [markdown]
# ### 1. Two fair coin flips produce exactly two heads (0,0)

# %%
# simulate 1 million tests of two fair coin flips
#  nprandint(outcomes, #of test size, # of flips)
tests = np.random.randint(2, size=(int(1e6), 2))

# sums of all tests
test_sums = tests.sum(axis=1)

# proportion of tests that produced exactly two heads
(test_sums == 0).mean()
# Out:
# 0.250586

# %% [markdown]
# ### 2. Three fair coin flips produce exactly one head (0,1,1)

# %%
# simulate 1 million tests of three fair coin flips
tests = np.random.randint(2, size=(int(1e6), 3))

# sums of all tests
test_sums = tests.sum(axis=1)

# proportion of tests that produced exactly one head
(test_sums == 2).mean()
# Out:
# 0.375364

# %% [markdown]
#  ### 3. Three biased coin flips with P(H) = 0.6 produce exactly one head

# %%
 # simulate 1 million tests of three biased coin flips
# hint: use np.random.choice()
tests = np.random.choice([0, 1], size=(int(1e6), 3), p=[0.6, 0.4])

# sums of all tests
test_sums = tests.sum(axis=1)

# proportion of tests that produced exactly one head
(test_sums == 2).mean()
# Out:
# 0.287626

# %% [markdown]
#  ### 4. A die rolls an even number

# %%
# simulate 1 million tests of one die roll
tests = np.random.choice(np.arange(1, 7), size=int(1e6))

# proportion of tests that produced an even number  % = remainder 2.5 % 2 = 0.5
(tests % 2 == 0).mean()
# Out:
# 0.500192

# %% [markdown]
# ### 5. Two dice roll a double

# %%
# simulate the first million die rolls
first = np.random.choice(np.arange(6), size=int(1e6))

# simulate the second million die rolls
second = np.random.choice(np.arange(6), size=int(1e6))

# proportion of tests where the 1st and 2nd die rolled the same number
(first == second).mean()
# Out:
# 0.166343

# %% [markdown]
# # Simulating Many Coin Flips

# %%
# number of heads from 10 fair coin flips
# the function returns teh number of success so 4 means in 10 flips 4 times head was coming
np.random.binomial(10, 0.5)
# Out:
# 7

# %%
# results from 20 tests with 10 coin flips
# the 20 represent the tzest size so 20 times 10 times flipping a coin
np.random.binomial(10, 0.5, 20)
# Out:
# array([7, 7, 6, 7, 3, 2, 9, 4, 6, 4, 7, 3, 6, 5, 7, 5, 4, 7, 4, 7])

# %%
# mean number of heads from the 20 tests
np.random.binomial(10, 0.5, 20).mean()
# Out:
# 4.7

# %%
# reflects the fairness of the coin more closely as # tests increases
np.random.binomial(10, 0.5, 1000000).mean()
# Out:
# 5.000134

# %%
plt.hist(np.random.binomial(10, 0.5, 1000000));

# %%
# gets more narrow as number of flips increase per test
plt.hist(np.random.binomial(100, 0.5, 10000000));

# %% [markdown]
# # Binomial Distributions
# Use NumPy to create simulations and compute proportions for the following outcomes. The first one is done for you.

# %% [markdown]
# ### 1. A fair coin flip produces heads

# %%
# simulate 1 million tests of one fair coin flip
# remember, the output of these tests are the # successes, or # heads
tests = np.random.binomial(1, 0.5, int(1e6))

# proportion of tests that produced heads
(tests == 1).mean()
# Out:
# 0.500441

# %% [markdown]
# ### 2. Five fair coin flips produce exactly one head

# %%
# simulate 1 million tests of five fair coin flips
tests = np.random.binomial(5, 0.5, int(1e6))


# proportion of tests that produced 1 head
(tests == 1).mean()
# Out:
# 0.156602

# %% [markdown]
# ### 3. Ten fair coin flips produce exactly four heads

# %%
# simulate 1 million tests of ten fair coin flips
tests = np.random.binomial(10, 0.5, int(1e6))


# proportion of tests that produced 4 heads
(tests == 4).mean()
# Out:
# 0.204792

# %% [markdown]
# ### 4. Five biased coin flips with P(H) = 0.8 produce exactly five heads

# %%
# simulate 1 million tests of five biased coin flips
tests =  np.random.binomial(5, 0.8, int(1e6))

# proportion of tests that produced 5 heads
(tests == 5).mean()
# Out:
# 0.32872

# %% [markdown]
# ### 5. Ten biased coin flips with P(H) = 0.15 produce at least 3 heads

# %%
# simulate 1 million tests of ten biased coin flips
tests = np.random.binomial(10, 0.15, int(1e6))

# proportion of tests that produced at least 3 heads
(tests >= 3).mean()
# Out:
# 0.17971

# %% [markdown]
# # Cancer Test Results

# %%
# load dataset
import pandas as pd
df = pd.read_csv('cancer_test_data.csv')

df.head(3)
# Out:
#    patient_id test_result  has_cancer
# 0       79452    Negative       False
# 1       81667    Positive        True
# 2       76297    Negative       False

# %%
df.patient_id.unique().shape
# Out:
# (2914,)

# %%
# number of patients with cancer
df.has_cancer.sum()
(df['has_cancer'] == True).sum()
# Out:
# 306

# %%
# number of patients without cancer
(df.has_cancer == False).sum()
# Out:
# 2608

# %%
# proportion of patients without cancer
1 - df.has_cancer.mean()
# Out:
# 0.8949897048730268

# %%
1-(1 - df.has_cancer.mean())
# Out:
# 0.10501029512697324

# %%
# proportion of patients with cancer who test positive
(df.query('has_cancer')['test_result'] == 'Positive').mean()
# Out:
# 0.9052287581699346

# %%
# proportion of patients with cancer who test negative
(df.query('has_cancer')['test_result'] == 'Negative').mean()
# Out:
# 0.09477124183006536

# %%
# proportion of patients without cancer who test positive
(df.query('has_cancer == False')['test_result'] == 'Positive').mean()
# Out:
# 0.2036042944785276

# %%
# proportion of patients without cancer who test negative
(df.query('has_cancer == False')['test_result'] == 'Negative').mean()
# Out:
# 0.7963957055214724

# %% [markdown]
# # Conditional Probability & Bayes Rule Quiz

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# What proportion of patients who tested positive has cancer?  P(cancer|positive)

# %%
prior_cancer = 0.105
prior_no_cancer = 0.895
p_positive_cancer = 0.905
p_positive_no_cancer = 0.204

marginal_pos_c = prior_cancer * p_positive_cancer
marginal_pos_no_c = prior_no_cancer * p_positive_no_cancer
normalizer = marginal_pos_c + marginal_pos_no_c

p_cancer_positive = marginal_pos_c / normalizer
p_no_cancer_positive = marginal_pos_no_c / normalizer

p_cancer_positive
# Out:
# 0.34230291241151994

# %%
# comparison 
df.query('test_result == "Positive"')['has_cancer'].mean()
# Out:
# 0.34282178217821785

# %%
# What proportion of patients who tested positive doesn't have cancer? P(~cancer|positive)

# %%
p_no_cancer_positive
# Out:
# 0.65769708758848

# %%
# Comparison
1 - df.query('test_result == "Positive"')['has_cancer'].mean()
# Out:
# 0.6571782178217822

# %%
# What proportion of patients who tested negative has cancer? P(cancer|negative)

# %%
prior_cancer = 0.105
prior_no_cancer = 0.895
p_neg_cancer = 0.095
p_neg_no_cancer = 0.796

marginal_neg_cancer = prior_cancer * p_neg_cancer 
marginal_neg_no_cancer = prior_no_cancer * p_neg_no_cancer
normalizer = marginal_neg_cancer + marginal_neg_no_cancer

p_cancer_neg = marginal_neg_cancer / normalizer
p_no_cancer_neg = marginal_neg_no_cancer / normalizer
p_cancer_neg
# Out:
# 0.013808235106832134

# %%
# comparison 
df.query('test_result == "Negative"')['has_cancer'].mean()
# Out:
# 0.013770180436847104

# %%
# What proportion of patients who tested negative doesn't have cancer? P(~cancer|negative)

# %%
p_no_cancer_neg
# Out:
# 0.986191764893168

# %%
#Comparsion
1 - df.query('test_result == "Negative"')['has_cancer'].mean()
# Out:
# 0.9862298195631529
